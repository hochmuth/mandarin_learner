# %%
import pandas as pd

# %%
seed_pd = pd.read_csv("../app/data/characters.csv")

# %%
seed_pd["status"] = "known"

# %%
new_chars = ["那", "哪", "这", "有", "没", "饭", "呢"]

seed_pd.loc[seed_pd["character"].isin(new_chars), "status"] = "new"

# %%
# Out:
#    character pinyin            meaning  level status
# 0          我     wǒ             I / me      1  known
# 1          你     nǐ                you      1  known
# 2          他     tā                 he      1  known
# 3          她     tā                she      1  known
# 4          是    shì              to be      1  known
# 5          不     bù                not      1  known
# 6          有    yǒu            to have      1    new
# 7          这    zhè               this      1    new
# 8          那     nà               that      1    new
# 9          哪     nǎ              which      1    new
# 10         人    rén             person      1  known
# 11         大     dà                big      1  known
# 12         小   xiǎo              small      1  known
# 13         好    hǎo               good      1  known
# 14         吃    chī                eat      1  known
# 15         喝     hē              drink      1  known
# 16         看    kàn               look      1  known
# ...
